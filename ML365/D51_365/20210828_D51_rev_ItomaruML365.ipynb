# %%
# !pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (4.7.3)
# Requirement already satisfied: lxml in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from pytrends) (4.6.3)
# Requirement already satisfied: requests in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from pytrends) (2.26.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from pytrends) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from pandas>=0.25->pytrends) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from pandas>=0.25->pytrends) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from requests->pytrends) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from requests->pytrends) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from requests->pytrends) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\itomaru\anaconda3\envs\tf\lib\site-packages (from requests->pytrends) (1.26.6)

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Deep Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Deep Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Deep Learning
# geoName
# China                  100
# South Korea             18
# Singapore               11
# Hong Kong                8
# Israel                   7
# St. Helena               7
# Ethiopia                 7
# Taiwan                   6
# Tunisia                  6
# India                    4

# %%
data.reset_index().plot(x="geoName", y="Deep Learning", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Deep Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Deep Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Deep Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
